# %% [markdown]
# # Ejercicio 2.7.6
#
# Para los datos de Datarium marketing, analiza los supuestos. Explica tus resultados y sube tus respuestas a github.
#
# Verificación del supuesto de no colinealidad.

# %%
DatasetMarketing <- read.csv('./marketing_dataset.csv')

pairs(DatasetMarketing)
# Out:
# plot without title

# %%
LinearModel_1 <- lm("sales ~ youtube + facebook + newspaper",DatasetMarketing)
summary(LinearModel_1)
# Out:
# Call:
# lm(formula = "sales ~ youtube + facebook + newspaper", data = DatasetMarketing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.5932  -1.0690   0.2902   1.4272   3.3951
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.526667   0.374290   9.422   <2e-16 ***
# youtube      0.045765   0.001395  32.809   <2e-16 ***
# facebook     0.188530   0.008611  21.893   <2e-16 ***
# newspaper   -0.001037   0.005871  -0.177     0.86
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.023 on 196 degrees of freedom
# Multiple R-squared:  0.8972,	Adjusted R-squared:  0.8956
# F-statistic: 570.3 on 3 and 196 DF,  p-value: < 2.2e-16

# %%
LinearModel_2 <- lm("sales ~ youtube + facebook",DatasetMarketing)
summary(LinearModel_2)
# Out:
# Call:
# lm(formula = "sales ~ youtube + facebook", data = DatasetMarketing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.5572  -1.0502   0.2906   1.4049   3.3994
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.50532    0.35339   9.919   <2e-16 ***
# youtube      0.04575    0.00139  32.909   <2e-16 ***
# facebook     0.18799    0.00804  23.382   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.018 on 197 degrees of freedom
# Multiple R-squared:  0.8972,	Adjusted R-squared:  0.8962
# F-statistic: 859.6 on 2 and 197 DF,  p-value: < 2.2e-16

# %%
anova(LinearModel_1,LinearModel_2)
# Out:
#   Res.Df RSS      Df Sum of Sq  F          Pr(>F)
# 1 196    801.8284 NA         NA         NA        NA
# 2 197    801.9561 -1 -0.1277527 0.03122805 0.8599151

# %% [markdown]
# Se realizaron dos modelos: uno usando todas las variables y otro sin la variable `newspaper`. Se usó la función `summary` donde se detectó cuáles son los coeficientes significativos y además que se cuenta con un $R^2_{Adj}$ alto.
#
# Aplicando una prueba de significancia sobre los modelos se tiene que el modelo sin la variable `newspaper` verifica el supuesto de no colinealidad y sin que se deteriore el propio modelo.
